# %% [markdown]
# # Plotting PyPSA results
#
# ### Jupyter scripts need to be improved

# %%
###### algunas cosas cambian si pongo como comentarios el import de geoviews y hvplot

import logging
import os

import pypsa
import yaml
import pandas as pd
import geopandas as gpd
#import geoviews as gv
#import hvplot.pandas 
import numpy as np
import scipy as sp
import networkx as nx

# plotting stuff
import matplotlib.pyplot as plt

plt.style.use("bmh")
import seaborn as sns  ###
import cartopy.crs as ccrs

sns.set(style="darkgrid")

from scipy.sparse import csgraph
from itertools import product

from shapely.geometry import Point, LineString
import shapely, shapely.prepared, shapely.wkt

logger = logging.getLogger(__name__)

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 70)

import sys

sys.path.append("../")  # to import helpers
from scripts._helpers import sets_path_to_root

sets_path_to_root("pypsa-africa")

max_node_size = 1.0  # maximum size of a node for plotting purposes [used in plots]
# Out:
# This is the repository path:  C:\Users\Lenovo\Desktop\pypsa-africa
# Had to go 0 folder(s) up.

# %%
# utility function for nice plotting


def normalize_node_size(values, max_node_size=max_node_size):
    return values / values.max() * max_node_size

# %% [markdown]
# # Load all networks

# %%
# add_electricity_network = os.getcwd() + '/networks/elec.nc'
# clustered_network = os.getcwd() + '/networks/elec_s_20.nc'
solved_network = os.getcwd() + "/results/networks/elec_s_20_ec_lcopt_Co2L-3H.nc"

# n_add_el = pypsa.Network(add_electricity_network)
# n_cluster = pypsa.Network(clustered_network)
n_solve = pypsa.Network(solved_network)
# Out:
# INFO:pypsa.io:Imported network elec_s_20_ec_lcopt_Co2L-3H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %% [markdown]
# # Solved network

# %%
n = n_solve

# %%
n.global_constraints
# Out:
#                  sense    constant            mu            type  \
# GlobalConstraint
# CO2Limit            <=  77500000.0  1.750914e-09  primary_energy
#
#                   investment_period carrier_attribute
# GlobalConstraint
# CO2Limit                        NaN     co2_emissions

# %%
################# to be defined

# EURO/MWh
n.objective / n.loads_t.p.sum().sum()
# Out:
# 62.61919869784461

# %% [markdown]
# ### Spatial temporal resolution

# %%
##### augmented lines in green (can be disabled)

n.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x15a391a8820>,
#  <matplotlib.collections.LineCollection at 0x15a39187460>,
#  <matplotlib.collections.LineCollection at 0x15a391843d0>)

# %%
# temporal resolution - timesteps
len(n.snapshots)
# Out:
# 2920

# %% [markdown]
# ### Overview components

# %%
for c in n.iterate_components(list(n.components.keys())[2:]):
    print("Component '{}' has {} entries".format(c.name, len(c.df)))
# Out:
# Component 'Bus' has 60 entries
# Component 'Carrier' has 14 entries
# Component 'GlobalConstraint' has 1 entries
# Component 'Line' has 23 entries
# Component 'LineType' has 32 entries
# Component 'TransformerType' has 14 entries
# Component 'Link' has 95 entries
# Component 'Load' has 20 entries
# Component 'Generator' has 117 entries
# Component 'StorageUnit' has 12 entries
# Component 'Store' has 40 entries

# %% [markdown]
# ### Energy balance

# %%
##### que es stores_t??? losses?

n.stores_t.p.sum()
# Out:
# Store
# AR 0 H2          3.469447e-18
# AR 1 H2          0.000000e+00
# AR 10 H2         6.938894e-18
# AR 11 H2         0.000000e+00
# AR 12 H2         0.000000e+00
# AR 13 H2        -1.040834e-17
# AR 2 H2          2.428613e-17
# AR 3 H2          0.000000e+00
# AR 4 H2         -3.469447e-18
# AR 5 H2          0.000000e+00
# AR 6 H2          0.000000e+00
# AR 7 H2          0.000000e+00
# AR 8 H2          0.000000e+00
# AR 9 H2          0.000000e+00
# BO 0 H2         -3.469447e-17
# PE 0 H2          0.000000e+00
# PE 1 H2          0.000000e+00
# PE 2 H2          0.000000e+00
# PE 3 H2          0.000000e+00
# PE 4 H2          0.000000e+00
# AR 0 battery    -1.040834e-17
# AR 1 battery    -8.673617e-19
# AR 10 battery   -9.974660e-18
# AR 11 battery   -1.474515e-17
# AR 12 battery   -2.081668e-17
# AR 13 battery   -1.127570e-17
# AR 2 battery    -2.255141e-17
# AR 3 battery     3.469447e-18
# AR 4 battery    -2.341877e-17
# AR 5 battery     4.683753e-17
# AR 6 battery     4.770490e-18
# AR 7 battery    -2.949030e-17
# AR 8 battery    -8.673617e-18
# AR 9 battery    -9.540979e-18
# BO 0 battery     1.665335e-16
# PE 0 battery     5.898060e-17
# PE 1 battery     3.122502e-17
# PE 2 battery    -7.632783e-17
# PE 3 battery    -2.081668e-17
# PE 4 battery     1.353084e-16
# dtype: float64

# %%
# Difference between total load and generation
# losses = n.stores_t
n.generators_t.p.sum().sum() - n.loads_t.p.sum().sum()  # - substract storage losses


n.generators
# Out:
#                 p_nom_max        weight         p_nom   capital_cost   bus  \
# Generator
# AR 0 CCGT             NaN      0.000000  4.248700e+02       0.000000  AR 0
# AR 0 oil              NaN      0.000000  4.302508e+02       0.000000  AR 0
# AR 0 onwind  2.036501e+05  68094.283227  0.000000e+00  109295.569252  AR 0
# AR 0 solar   1.280590e+05  20104.114745  0.000000e+00   55064.071419  AR 0
# AR 1 CCGT             inf      0.000000  1.730000e+01       0.000000  AR 1
# ...                   ...           ...           ...            ...   ...
# PE 0 load             inf           NaN  1.000000e+09       0.000000  PE 0
# PE 1 load             inf           NaN  1.000000e+09       0.000000  PE 1
# PE 2 load             inf           NaN  1.000000e+09       0.000000  PE 2
# PE 3 load             inf           NaN  1.000000e+09       0.000000  PE 3
# PE 4 load             inf           NaN  1.000000e+09       0.000000  PE 4
#
#              efficiency  marginal_cost carrier  p_nom_extendable control  \
# Generator
# AR 0 CCGT         0.500      47.209584    CCGT             False   Slack
# AR 0 oil          0.393     130.237035     oil             False
# AR 0 onwind       1.000       0.024205  onwind              True
# AR 0 solar        1.000       0.019700   solar              True
# AR 1 CCGT         0.500      47.210010    CCGT             False
# ...                 ...            ...     ...               ...     ...
# PE 0 load         1.000    8000.010271    load             False      PQ
# PE 1 load         1.000    8000.010756    load             False      PQ
# PE 2 load         1.000    8000.010877    load             False      PQ
# PE 3 load         1.000    8000.010521    load             False      PQ
# PE 4 load         1.000    8000.009493    load             False      PQ
#
#                 p_nom_opt   sign  build_year  min_up_time  min_down_time  \
# Generator
# AR 0 CCGT    4.248700e+02  1.000           0            0              0
# AR 0 oil     4.302508e+02  1.000           0            0              0
# AR 0 onwind  1.012345e+03  1.000           0            0              0
# AR 0 solar   4.827111e-02  1.000           0            0              0
# AR 1 CCGT    1.730000e+01  1.000           0            0              0
# ...                   ...    ...         ...          ...            ...
# PE 0 load    1.000000e+09  0.001           0            0              0
# PE 1 load    1.000000e+09  0.001           0            0              0
# PE 2 load    1.000000e+09  0.001           0            0              0
# PE 3 load    1.000000e+09  0.001           0            0              0
# PE 4 load    1.000000e+09  0.001           0            0              0
#
#              up_time_before  down_time_before type  p_nom_min  p_min_pu  \
# Generator
# AR 0 CCGT                 1                 0             0.0       0.0
# AR 0 oil                  1                 0             0.0       0.0
# AR 0 onwind               1                 0             0.0       0.0
# AR 0 solar                1                 0             0.0       0.0
# AR 1 CCGT                 1                 0             0.0       0.0
# ...                     ...               ...  ...        ...       ...
# PE 0 load                 1                 0             0.0       0.0
# PE 1 load                 1                 0             0.0       0.0
# PE 2 load                 1                 0             0.0       0.0
# PE 3 load                 1                 0             0.0       0.0
# PE 4 load                 1                 0             0.0       0.0
#
#              p_max_pu  p_set  q_set  lifetime  committable  start_up_cost  \
# Generator
# AR 0 CCGT         1.0    0.0    0.0       inf        False            0.0
# AR 0 oil          1.0    0.0    0.0       inf        False            0.0
# AR 0 onwind       1.0    0.0    0.0       inf        False            0.0
# AR 0 solar        1.0    0.0    0.0       inf        False            0.0
# AR 1 CCGT         1.0    0.0    0.0       inf        False            0.0
# ...               ...    ...    ...       ...          ...            ...
# PE 0 load         1.0    0.0    0.0       inf        False            0.0
# PE 1 load         1.0    0.0    0.0       inf        False            0.0
# PE 2 load         1.0    0.0    0.0       inf        False            0.0
# PE 3 load         1.0    0.0    0.0       inf        False            0.0
# PE 4 load         1.0    0.0    0.0       inf        False            0.0
#
#              shut_down_cost  ramp_limit_up  ramp_limit_down  \
# Generator
# AR 0 CCGT               0.0            NaN              NaN
# AR 0 oil                0.0            NaN              NaN
# AR 0 onwind             0.0            NaN              NaN
# AR 0 solar              0.0            NaN              NaN
# AR 1 CCGT               0.0            NaN              NaN
# ...                     ...            ...              ...
# PE 0 load               0.0            NaN              NaN
# PE 1 load               0.0            NaN              NaN
# PE 2 load               0.0            NaN              NaN
# PE 3 load               0.0            NaN              NaN
# PE 4 load               0.0            NaN              NaN
#
#              ramp_limit_start_up  ramp_limit_shut_down
# Generator
# AR 0 CCGT                    1.0                   1.0
# AR 0 oil                     1.0                   1.0
# AR 0 onwind                  1.0                   1.0
# AR 0 solar                   1.0                   1.0
# AR 1 CCGT                    1.0                   1.0
# ...                          ...                   ...
# PE 0 load                    1.0                   1.0
# PE 1 load                    1.0                   1.0
# PE 2 load                    1.0                   1.0
# PE 3 load                    1.0                   1.0
# PE 4 load                    1.0                   1.0
#
# [117 rows x 31 columns]

# %% [markdown]
# ### Total installed generator capacity

# %%
gen_cap = n.generators.groupby(["carrier"]).sum()
gen_cap
# Out:
#             p_nom_max        weight         p_nom  capital_cost  efficiency  \
# carrier
# CCGT              NaN  0.000000e+00  1.046207e+04  0.000000e+00       8.000
# OCGT              NaN  0.000000e+00  7.127537e+03  0.000000e+00       3.120
# coal              NaN  0.000000e+00  2.359200e+03  0.000000e+00       2.320
# load              NaN  0.000000e+00  2.000000e+10  0.000000e+00      20.000
# oil               NaN  0.000000e+00  1.244730e+04  0.000000e+00       5.895
# onwind   1.015664e+07  1.976444e+06  0.000000e+00  2.185911e+06      20.000
# ror               NaN  6.145570e+03  6.145570e+03  3.522229e+06      11.700
# solar    5.027147e+06  8.764364e+05  0.000000e+00  1.101281e+06      20.000
#
#          marginal_cost  p_nom_extendable     p_nom_opt   sign  build_year  \
# carrier
# CCGT        755.361360                 0  1.046207e+04  16.00           0
# OCGT        467.155068                 0  7.127537e+03   8.00           0
# coal        120.566860                 0  2.359200e+03   5.00           0
# load     160000.203826                 0  2.000000e+10   0.02           0
# oil        1953.549068                 0  1.244730e+04  15.00           0
# onwind        0.496760                20  1.328645e+04  20.00           0
# ror           0.129543                 0  6.145570e+03  13.00           0
# solar         0.396020                20  1.915653e+04  20.00           0
#
#          min_up_time  min_down_time  up_time_before  down_time_before  \
# carrier
# CCGT               0              0              16                 0
# OCGT               0              0               8                 0
# coal               0              0               5                 0
# load               0              0              20                 0
# oil                0              0              15                 0
# onwind             0              0              20                 0
# ror                0              0              13                 0
# solar              0              0              20                 0
#
#          p_nom_min  p_min_pu  p_max_pu  p_set  q_set  lifetime  committable  \
# carrier
# CCGT           0.0       0.0      16.0    0.0    0.0       NaN            0
# OCGT           0.0       0.0       8.0    0.0    0.0       NaN            0
# coal           0.0       0.0       5.0    0.0    0.0       NaN            0
# load           0.0       0.0      20.0    0.0    0.0       NaN            0
# oil            0.0       0.0      15.0    0.0    0.0       NaN            0
# onwind         0.0       0.0      20.0    0.0    0.0       NaN            0
# ror            0.0       0.0      13.0    0.0    0.0       NaN            0
# solar          0.0       0.0      20.0    0.0    0.0       NaN            0
#
#          start_up_cost  shut_down_cost  ramp_limit_up  ramp_limit_down  \
# carrier
# CCGT               0.0             0.0            0.0              0.0
# OCGT               0.0             0.0            0.0              0.0
# coal               0.0             0.0            0.0              0.0
# load               0.0             0.0            0.0              0.0
# oil                0.0             0.0            0.0              0.0
# onwind             0.0             0.0            0.0              0.0
# ror                0.0             0.0            0.0              0.0
# solar              0.0             0.0            0.0              0.0
#
#          ramp_limit_start_up  ramp_limit_shut_down
# carrier
# CCGT                    16.0                  16.0
# OCGT                     8.0                   8.0
# coal                     5.0                   5.0
# load                    20.0                  20.0
# oil                     15.0                  15.0
# onwind                  20.0                  20.0
# ror                     13.0                  13.0
# solar                   20.0                  20.0

# %%
n.stores_t.p
# Out:
# Store                 AR 0 H2   AR 1 H2  AR 10 H2  AR 11 H2  AR 12 H2  \
# snapshot
# 2013-01-01 00:00:00  0.000266  0.000284  0.004087  0.000162  0.001105
# 2013-01-01 03:00:00  0.000221 -0.000070  0.004173  0.000033  0.000070
# 2013-01-01 06:00:00  0.000259 -0.000048  0.004118  0.000059  0.000081
# 2013-01-01 09:00:00  0.000259 -0.000038  0.003978  0.000048  0.000069
# 2013-01-01 12:00:00  0.000241 -0.000082  0.004040  0.000018  0.000029
# ...                       ...       ...       ...       ...       ...
# 2013-12-31 09:00:00  0.000213 -0.000034  0.001670  0.000038  0.000118
# 2013-12-31 12:00:00  0.000158 -0.000079  0.001611 -0.000023  0.000066
# 2013-12-31 15:00:00  0.000131 -0.000133  0.001584 -0.000053  0.000115
# snapshot
# 2013-01-01 00:00:00      0.000651      0.001868      0.006590      0.001459
# 2013-01-01 03:00:00     -0.000413      0.000353     -0.006377      0.002069
# 2013-01-01 06:00:00     -0.000005      0.000264     -0.005499     -0.003925
# 2013-01-01 09:00:00      0.000154      0.000083      0.010935      0.004780
# 2013-01-01 12:00:00     -0.000169     -0.000196     -0.004317      0.000825
# ...                           ...           ...           ...           ...
# 2013-12-31 09:00:00      0.000194      0.000143      0.011539      0.004505
# 2013-12-31 12:00:00      0.000096      0.000046     -0.004505     -0.002275
# 2013-12-31 15:00:00     -0.000412      0.000270     -0.002650     -0.000678
# 2013-12-31 18:00:00     -0.000164      0.001393     -0.005426     -0.002624
# 2013-12-31 21:00:00     -0.000037     -0.004442      0.006722      0.002144
#
# Store                PE 1 battery  PE 2 battery  PE 3 battery  PE 4 battery
# snapshot
# 2013-01-01 00:00:00      0.001240      0.001577      0.001284      0.001249
# 2013-01-01 03:00:00      0.001831      0.002197      0.001866      0.001835
# 2013-01-01 06:00:00     -0.003492     -0.003903     -0.003474     -0.003488
# 2013-01-01 09:00:00      0.004212      0.004571      0.004254      0.004191
# 2013-01-01 12:00:00      0.000894      0.001167      0.000885      0.000879
# ...                           ...           ...           ...           ...
# 2013-12-31 09:00:00      0.003954      0.004466      0.004011      0.003992
# 2013-12-31 12:00:00     -0.001960     -0.002012     -0.001958     -0.001933
# 2013-12-31 15:00:00     -0.000627     -0.000782     -0.000679     -0.000635
# 2013-12-31 18:00:00     -0.002251     -0.002902     -0.002335     -0.002277
# 2013-12-31 21:00:00      0.001882      0.001995      0.001852      0.001879
#
# [2920 rows x 40 columns]

# %%
n.generators_t.p_max_pu.groupby(n.generators.carrier, axis=1).mean().plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
# If 0, all renewable capacity potential is used
n.generators.p_nom_max.sum() - n.generators.p_nom_opt.sum()
# Out:
# inf

# %%
n.loads_t.p.sum().sum()
# Out:
# 93050599.29425743

# %%
n.generators_t.p.sum().sum()
# Out:
# 67682545.15837397

# %%
#### pq la multiplicacion?

n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom.sum() * 0.0000003
# Out:
# bus   carrier
# AR 0  CCGT         0.000127
#       load       300.000000
#       oil          0.000129
#       onwind       0.000000
#       solar        0.000000
#                     ...
# PE 4  OCGT         0.000048
#       load       300.000000
#       onwind       0.000000
#       ror          0.000109
#       solar        0.000000
# Name: p_nom, Length: 117, dtype: float64

# %%
######################################################## se importaron librerias nuevamente por los errores en celdas anteriores
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
########################################################

fig, ax = plt.subplots(
    figsize=(10, 10),
    subplot_kw={
        "projection": ccrs.PlateCarree()
    },  # PlateCarree(default), Mercator, Orthographic
)

# loading = (n3.lines_t.p0.abs().mean().sort_index() / (n3.lines.s_nom_opt*n.lines.s_max_pu).sort_index()).fillna(0.)

n.plot(
    margin=0.1,
    ax=None,
    geomap=True,  #'10m' leads to a beautiful high resolution map
    projection=None,
    bus_colors="cadetblue",
    bus_alpha=1,
    bus_sizes=normalize_node_size(
        n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom_opt.sum()
    ),
    bus_cmap=None,
    line_colors="rosybrown",
    link_colors="darkseagreen",  # loading
    transformer_colors="orange",
    line_widths=n.lines.s_nom_opt / 3e2,
    link_widths=1.5,
    transformer_widths=1.5,
    line_cmap=None,
    link_cmap=None,  # plt.cm.virdis (colordmap for line loading)
    transformer_cmap=None,
    flow=None,
    branch_components=None,
    layouter=None,
    title="Generator Map",
    boundaries=None,
    geometry=False,
    jitter=None,
    color_geomap=True,
)  # None or True

ax.axis("off");
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [19], in <cell line: 15>()
#       6 fig, ax = plt.subplots(
#       7     figsize=(10, 10),
#       8     subplot_kw={
#       9         "projection": ccrs.PlateCarree()
#      10     },  # PlateCarree(default), Mercator, Orthographic
#      11 )
#      13 # loading = (n3.lines_t.p0.abs().mean().sort_index() / (n3.lines.s_nom_opt*n.lines.s_max_pu).sort_index()).fillna(0.)
# ---> 15 n.plot(
#      16     margin=0.1,
#      17     ax=None,
#      18     geomap=True,  #'10m' leads to a beautiful high resolution map
#      19     projection=None,
#      20     bus_colors="cadetblue",
#      21     bus_alpha=1,
#      22     bus_sizes=normalize_node_size(
#      23         n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom_opt.sum()
#      24     ),
#      25     bus_cmap=None,
#      26     line_colors="rosybrown",
#      27     link_colors="darkseagreen",  # loading
#      28     transformer_colors="orange",
#      29     line_widths=n.lines.s_nom_opt / 3e2,
#      30     link_widths=1.5,
#      31     transformer_widths=1.5,
#      32     line_cmap=None,
#      33     link_cmap=None,  # plt.cm.virdis (colordmap for line loading)
#      34     transformer_cmap=None,
#      35     flow=None,
#      36     branch_components=None,
#      37     layouter=None,
#      38     title="Generator Map",
#      39     boundaries=None,
#      40     geometry=False,
#      41     jitter=None,
#      42     color_geomap=True,
#      43 )  # None or True
#      45 ax.axis("off")
#
# File ~\anaconda3\envs\pypsa-africa\lib\site-packages\pypsa\plot.py:223, in plot(n, margin, ax, geomap, projection, bus_colors, bus_alpha, bus_sizes, bus_cmap, line_colors, link_colors, transformer_colors, line_widths, link_widths, transformer_widths, line_cmap, link_cmap, transformer_cmap, flow, branch_components, layouter, title, boundaries, geometry, jitter, color_geomap)
#     221 if not isinstance(bus_colors, pd.Series):
#     222     bus_colors = n.carriers.color.dropna()
# --> 223 assert bus_sizes.index.levels[1].isin(bus_colors.index).all(), (
#     224     "Colors not defined for all elements in the second MultiIndex "
#     225     "level of bus_sizes, please make sure that all the elements are "
#     226     "included in bus_colors or in n.carriers.color"
#     227 )
#     229 bus_sizes = bus_sizes.sort_index(level=0, sort_remaining=False)
#     230 if geomap:
#
# AssertionError: Colors not defined for all elements in the second MultiIndex level of bus_sizes, please make sure that all the elements are included in bus_colors or in n.carriers.color

# %% [markdown]
# ### Demand

# %%
type(n.generators.iloc[:, :].groupby(["bus"]).p_nom_opt.sum())
# Out:
# pandas.core.series.Series

# %%
n.loads_t.p_set.loc["2013-01-01":"2013-01-27","BO 0"].plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
type(n.loads_t.p_set.sum())
# Out:
# pandas.core.series.Series

# %%
a = n.loads_t.p_set.sum().rename("load").rename_axis("bus")
a.rename("load", inplace=True)
a.rename_axis("bus", inplace=True)
a
# Out:
# bus
# AR 0     2.856281e+06
# AR 1     3.324431e+06
# AR 10    2.323003e+05
# AR 11    4.284589e+06
# AR 12    3.860456e+06
# AR 13    7.730291e+05
# AR 2     2.544510e+06
# AR 3     7.209735e+06
# AR 4     3.981238e+06
# AR 5     2.021261e+07
# AR 6     7.164671e+06
# AR 7     3.143364e+06
# AR 8     2.002765e+06
# AR 9     5.511209e+06
# BO 0     3.779364e+06
# PE 0     4.449220e+06
# PE 1     3.693503e+06
# PE 2     3.901972e+06
# PE 3     5.362340e+06
# PE 4     4.763008e+06
# Name: load, dtype: float64

# %%
n.loads_t.p_set.sum().rename("load").rename_axis("bus")
# Out:
# bus
# AR 0     2.856281e+06
# AR 1     3.324431e+06
# AR 10    2.323003e+05
# AR 11    4.284589e+06
# AR 12    3.860456e+06
# AR 13    7.730291e+05
# AR 2     2.544510e+06
# AR 3     7.209735e+06
# AR 4     3.981238e+06
# AR 5     2.021261e+07
# AR 6     7.164671e+06
# AR 7     3.143364e+06
# AR 8     2.002765e+06
# AR 9     5.511209e+06
# BO 0     3.779364e+06
# PE 0     4.449220e+06
# PE 1     3.693503e+06
# PE 2     3.901972e+06
# PE 3     5.362340e+06
# PE 4     4.763008e+06
# Name: load, dtype: float64

# %%
n.generators.iloc[:, :].groupby(["bus"]).p_nom_opt.sum()

###### potencia maxima?
n.generators.iloc[:, :].groupby(["bus"]).p_max_pu.sum()
# Out:
# bus
# AR 0     5.0
# AR 1     5.0
# AR 10    6.0
# AR 11    5.0
# AR 12    7.0
# AR 13    7.0
# AR 2     7.0
# AR 3     6.0
# AR 4     6.0
# AR 5     7.0
# AR 6     6.0
# AR 7     8.0
# AR 8     6.0
# AR 9     7.0
# BO 0     3.0
# PE 0     4.0
# PE 1     4.0
# PE 2     7.0
# PE 3     6.0
# PE 4     5.0
# Name: p_max_pu, dtype: float64

# %%
fig, ax = plt.subplots(
    figsize=(10, 10),
    subplot_kw={
        "projection": ccrs.PlateCarree()
    },  # PlateCarree(default), Mercator, Orthographic
)

# loading = (n3.lines_t.p0.abs().mean().sort_index() / (n3.lines.s_nom_opt*n.lines.s_max_pu).sort_index()).fillna(0.)

n.plot(
    margin=0.1,
    ax=None,
    geomap=True,  #'10m' leads to a beautiful high resolution map
    projection=None,
    bus_colors="cadetblue",
    bus_alpha=1,
    bus_sizes=normalize_node_size(
        n.loads_t.p_set.sum().rename("load").rename_axis("bus")
    ),  # n.loads_t.p_set.sum().rename("load").rename_axis("bus")*.0000003,
    bus_cmap=None,
    line_colors="rosybrown",
    link_colors="darkseagreen",  # loading
    transformer_colors="orange",
    line_widths=n.lines.s_nom_opt / 3e2,
    link_widths=1.5,
    transformer_widths=1.5,
    line_cmap=None,
    link_cmap=None,  # plt.cm.virdis (colordmap for line loading)
    transformer_cmap=None,
    flow=None,
    branch_components=None,
    layouter=None,
    title="Generator Map",
    boundaries=None,
    geometry=False,
    jitter=None,
    color_geomap=True,
)  # None or True

ax.axis("off");

# %%
# backup
gen_serie = n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom_opt.sum()
load_serie = n.loads_t.p_set.sum().rename("load").rename_axis("bus")

load_serie = pd.Series(
    load_serie.values,
    index=pd.MultiIndex.from_tuples([(id, "AC load") for id in load_serie.index]),
)

tot_serie = pd.concat([gen_serie, load_serie])  # .groupby(['bus', 'carrier']).sum()

pd.concat([gen_serie, load_serie])
# Out:
# bus   carrier
# AR 0  CCGT       4.248700e+02
#       load       1.000000e+09
#       oil        4.302508e+02
#       onwind     1.012345e+03
#       solar      4.827111e-02
#                      ...
# PE 0  AC load    4.449220e+06
# PE 1  AC load    3.693503e+06
# PE 2  AC load    3.901972e+06
# PE 3  AC load    5.362340e+06
# PE 4  AC load    4.763008e+06
# Length: 137, dtype: float64

# %% [markdown]
# ### Plot of Average Marginal Price

# %%
now = n.snapshots[4]  ##one specific time

fig, ax = plt.subplots(1, 1, subplot_kw={"projection": ccrs.PlateCarree()})
fig.set_size_inches(6, 4)

n.plot(ax=ax, line_widths=pd.Series(0.5, n.lines.index))
plt.hexbin(
    n.buses.x,
    n.buses.y,
    gridsize=20,
    # C=n.buses_t.marginal_price.loc[now], #at one time (previous set up by scigrid)
    C=n.buses_t.marginal_price.sum()
    / len(n.snapshots[:]),  # Marginal price averaged over the whole year (My version)
    # - shows in which regions electricity will be cheap and where el. intensive companies should be placed.
    cmap=plt.cm.jet,
)

# for some reason the colorbar only works with graphs plt.plot
# and must be attached plt.colorbar

cb = plt.colorbar()
cb.set_label("Locational Marginal Price (EUR/MWh)")

# %% [markdown]
# ### Storage

# %%
n.stores_t.e.loc["2013-01-01":"2013-02-01"].sum(axis=1).plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
n.links.iloc[:].groupby(["carrier"]).p_nom_opt.sum()
# Out:
# carrier
# DC                    2064.563923
# H2 electrolysis          0.123614
# H2 fuel cell             0.142712
# battery charger          0.218003
# battery discharger       0.242225
# Name: p_nom_opt, dtype: float64
